# %%
# !pip install upsetjs_jupyter_widget 
# !pip install pandas
# jupyter labextension install @jupyter-widgets/jupyterlab-manager@3.0.0-alpha.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 5.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 5.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.5/505.5 kB 6.1 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 6.3 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...

# %%
from ipywidgets import interact
from upsetjs_jupyter_widget import UpSetJSWidget
import pandas as pd
w = UpSetJSWidget[str]()
# Out:
# /tmp/ipykernel_1354707/2143831396.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("/scratch/sah2p/datasets/2023_11_04_BurkeLab/output/9_DEG_new_v2/DEG_Summary/01_2FC_greaterthan_0.5_DEGenesList.csv",sep="\t")
filtered_df = df[['H1975_E07_vs_H1975_Veh', 'H1975_C36_vs_H1975_Veh', 'H1975_E07_vs_H1975_C36']]
filtered_df

w.from_dataframe(filtered_df)
# Out:
# UpSetJSWidget(value=None, combinations=[UpSetSetIntersection(name=H1975_E07_vs_H1975_Veh, sets={'H1975_E07_vs_…
