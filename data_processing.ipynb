# %%
import pandas as pd

file = "/scratch/sah2p/datasets/2023_11_04_BurkeLab/output/TF_identification/li_transciption_factors.csv"

df = pd.read_csv(file)

# %%
df
# Out:
# 0       IRF2
# 1       E2F1
# 2     STAT5B
# 3      GTF3A
# 4      STAT3
# 5       ATF5
# 6       DLX2
# 7       IRF7
# 8       LHX3
# 10    ZNF436
# 11      PAX2
# 12      TFAM
# 14     GATA6
# 15      LEF1
# 16      TCF4
# 18      IRF1
# 19    STAT5A
# 20     GATA1
# 21    POU3F2
# 22     CEBPA
# 23     STAT6
# 24     FOXR2
# 25       YY1
# 26      RFX7
# 27    ZNF101
# 28     NFXL1
# 30      SIX1
# 34       CIC
# 35     MYBL1
# 36       MAF
# 37     TERF1
# 39     ZNF16
# 40      PAX4
# 42       SP1
# 54     NR1I2
# 55     PIAS4
# 56      MSX1
# 60      HSF1
# 61    ZNF433
# 62       SRF
# 67     DMRT1
# 70      ELK1
# 71     NR1H4
# Name: TransciptionFactors, dtype: object

# %%
d
# Out:
# 0       IRF2
# 1       E2F1
# 2     STAT5B
# 3      GTF3A
# 4      STAT3
# 5       ATF5
# 6       DLX2
# 7       IRF7
# 8       LHX3
# 10    ZNF436
# 11      PAX2
# 12      TFAM
# 14     GATA6
# 15      LEF1
# 16      TCF4
# 18      IRF1
# 19    STAT5A
# 20     GATA1
# 21    POU3F2
# 22     CEBPA
# 23     STAT6
# 24     FOXR2
# 25       YY1
# 26      RFX7
# 27    ZNF101
# 28     NFXL1
# 30      SIX1
# 34       CIC
# 35     MYBL1
# 36       MAF
# 37     TERF1
# 39     ZNF16
# 40      PAX4
# 42       SP1
# 54     NR1I2
# 55     PIAS4
# 56      MSX1
# 60      HSF1
# 61    ZNF433
# 62       SRF
# 67     DMRT1
# 70      ELK1
# 71     NR1H4
# Name: TransciptionFactors, dtype: object

# %%
df.columns = ['TransciptionFactors']
df.to_csv(file)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1576760/2034633072.py in <module>
# ----> 1 df.columns = ['TransciptionFactors']
#       2 df.to_csv(file)
#
# /scratch/sah2p/miniconda3/miniconda3/envs/SNP_G2P-env/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5152         try:
#    5153             object.__getattribute__(self, name)
# -> 5154             return object.__setattr__(self, name, value)
#    5155         except AttributeError:
#    5156             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /scratch/sah2p/miniconda3/miniconda3/envs/SNP_G2P-env/lib/python3.7/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     562     def _set_axis(self, axis: int, labels: Index) -> None:
#     563         labels = ensure_index(labels)
# ...
